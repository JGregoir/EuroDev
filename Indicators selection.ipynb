# %% [markdown]
# ## Energy production stats
# IE.PPI.ENGY.CD - Investment in energy with private participation (current USdollar)
#
# EG.FEC.RNEW.ZS - Renewable energy consumption (% of total final energy consumption)
#
# EG.FEC.RNEW.ZS - GDP per unit of energy use (PPP dollar per kg of oil equivalent)
#
# EG.IMP.CONS.ZS - Energy imports, net (% of energy use)
#
# EG.USE.COMM.CL.ZS - Alternative and nuclear energy (% of total energy use)
#
# EG.USE.COMM.FO.ZS -	Fossil fuel energy consumption (% of total)
#
# EG.USE.CRNW.ZS - Combustible renewables and waste (% of total energy)
#
# EN.ATM.CO2E.PC - CO2 emissions (metric tons per capita)
#
# EN.ATM.NOXE.AG.ZS -	Agricultural nitrous oxide emissions (% of total)
#
#
#
# ## CO2 stats
#
# EN.CO2.BLDG.ZS - CO2 emissions from residential buildings and commercial and public services (% of total fuel combustion)
#
# EN.CO2.ETOT.ZS - CO2 emissions from electricity and heat production, total
#
# EN.CO2.MANF.ZS - CO2 emissions from manufacturing industries and construction
#
# EN.CO2.OTHX.ZS - CO2 emissions from other sectors, excluding residential buildings
# and commercial and public services
#
# EN.CO2.TRAN.ZS - CO2 emissions from transport
#
#
#
# ## International economic perspective => current account, debt, growth
#
# BM.GSR.ROYL.CD - Charges for the use of intellectual property, payments (BoP, current USdollar)
#
# BN.CAB.XOKA.CD - Current account balance (BoP, current USdollar)
#
# BN.CAB.XOKA.GD.ZS - Current account balance (% of GDP)
#
# DT.DOD.PVLX.CD - Present value of external debt (current USdollar)
#
# DT.DOD.PVLX.EX.ZS - Present value of external debt (% of exports of goods, services and primary income)
#
# GC.DOD.TOTL.CN - Central government debt, total (current LCU)
#
# GC.DOD.TOTL.GD.ZS - Central government debt, total (% of GDP)
#
# FD.AST.PRVT.GD.ZS -	Domestic credit to private sector by banks (% of GDP)
#
# NY.GDP.PCAP.CD - GDP per capita (current USdollars)(many indicators)
#
# NY.GDP.PCAP.KD.ZG - GDP per capita growth(annual %)
#
#
#
# ## Taxes
#
# GC.TAX.EXPT.CN - Taxes on exports (current LCU)
#
# GC.TAX.EXPT.ZS - Taxes on exports (% of tax revenue)
#
# GC.TAX.GSRV.CN - Taxes on goods and services (current LCU)
#
# GC.TAX.GSRV.RV.ZS - Taxes on goods and services (% of revenue)
#
# GC.TAX.GSRV.VA.ZS -	Taxes on goods and services (% value added of industry and services)
#
# GC.TAX.IMPT.ZS - Customs and other import duties (current LCU)
#
# GC.TAX.IMPT.CN - Customs and other import duties (% of tax revenue)
#
# GC.TAX.INTT.CN - Taxes on international trade (current LCU)
#
# GC.TAX.INTT.RV.ZS - Taxes on international trade (% of revenue)
#
# GC.TAX.TOTL.CN - Tax revenue (current LCU)
#
# GC.TAX.TOTL.GD.ZS - Tax revenue (% of GDP)
#
# GC.TAX.YPKG.CN - Taxes on income, profits and capital gains (current LCU)
#
# GC.TAX.YPKG.RV.ZS - Taxes on income, profits and capital gains (% of revenue)
#
# GC.TAX.YPKG.ZS - Taxes on income, profits and capital gains (% of total taxes)
#
# IC.FRM.INFM.ZS - Firms that do not report all sales for tax purposes (% of firms)
#
# TM.TAX - Tariff rates
#
# TM.VAL - imports (food fuel ICT / % of merch import)
#
# TX.VAL - Merchandise exports to country groups (% of total merchandise exports)
#
#
#
# ## How hard is it to start a business?
#
# IC.LGL.DURS	- Time required to enforce a contract (days)
#
# IC.REG.DURS - Time required to start a business (days)
#
# IC.REG.PROC - Start-up procedures to register a business (number)
#
# IC.TAX.DURS - Time to prepare and pay taxes (hours)
#
# IC.TAX.GIFT.ZS - Firms expected to give gifts in meetings with tax officials (% of firms) (corruption???)
#
# IC.TAX.TOTL.CP.ZS - Total tax rate (% of commercial profits)
#
#
#
# ## Where do private investments go?
#
# IE.PPI.ENGY.CD
#
# IE.PPI.TELE.CD
#
# IE.PPI.TRAN.CD
#
# IE.PPI.WATR.CD (current US dollar)
#
#
# ## CPIA metrics
#
# IQ.CPA.BREG.XQ - CPIA business regulatory environment rating (1=low to 6=high)
#
# IQ.CPA.DEBT.XQ - debt
#
# IQ.CPA.ECON.XQ - economic management cluster policy
#
# IQ.CPA.ENVR.XQ - environment friendly
#
# IQ.CPA.PADM.XQ - CPIA quality of public administration rating (1=low to 6=high)
#
# And many others
#
#
# ## Health
#
# SH.DYN.AIDS.ZS - Prevalence of HIV, total (% of population ages 15-49)
#
# SH.PRV.SMOK.MA - Smoking prevalence, males (% of adults)
#
# SH.PRV.SMOK.FE - Smoking prevalence, females (% of adults)
#
# SH.STA.DIAB.ZS - Diabetes prevalence (% of population ages 20 to 79)
#
# SH.XPD.EXTR.ZS - External resources for health (% of total expenditure on health)
#
#
# SH.XPD.PRIV.ZS - Health expenditure, private (% of GDP)
#
# SH.XPD.TOTL.ZS - Health expenditure, total (% of GDP)
#
# SH.XPD.PCAP - Health expenditure per capita (current USdollar)
#
#
#
# ## Employment
#
# SL.EMP.TOTL.SP.NE.ZS - Employment to population ratio, 15+, total (%, national estimate)(more in doc)
#
# SL.UEM.TOTL.NE.ZS - Unemployment, total (% of total labor force) (national estimate)
#
# SL.UEM.TOTL.ZS - Unemployment, total (% of total labor force)
#
#
# SL.EMP.WORK.ZS, SL.EMP.WORK.FE.ZS, SL.EMP.WORK.MA.ZS - Wage and salaried workers, total, Women, Males (% of total employed)
#
# SL.TLF.CACT.FM.NE.ZS - Ratio of female to male labor force participation rate (%) (national estimate)
#
# SL.TLF.PART.ZS - Part time employment, total (% of total employment)
#
# SL.UEM.1524.NE.ZS -	Unemployment, youth total (% of total labor force ages 15-24) (national estimate)
#
# SL.UEM.PRIM.ZS, SL.UEM.SECO.ZS, SL.UEM.TERT.ZS - Unemployment with primary, secondary and tertiary education (% of total unemployment)
#
# SP.POP.SCIE.RD.P6 - Researchers in R&D (per million people)
#
# SP.POP.TECH.RD.P6 - Technicians in R&D (per million people)
#
#
#
# ## Tourism
#
# ST.INT.ARVL - International tourism, number of arrivals
#
# ST.INT.RCPT.CD - International tourism, receipts (current USdollar)
#
# ST.INT.RCPT.XP.ZS -	International tourism, receipts (% of total exports)
#
#
#
# ## Migration
#
# SM.EMI.TERT.ZS - Emigration rate of tertiary educated (% of total tertiary educated population)
#
# SM.POP.REFG - Refugee population by country or territory of asylum
#
# SM.POP.TOTL - International migrant stock, total
#
# ST.INT.XPND.CD - International tourism, expenditures (current USdollar also %total imports)
#
#
# ## Education
#
# SE.ADT.1524.LT.ZS - Youth literacy rate, population 15-24 years, both sexes (%)
#
# SE.ADT.LITR.ZS - Adult literacy rate, population 15+ years, both sexes (%)
# massive amount of stats regarding school enrolment and dropouts
#
# SE.XPD.SECO.PC.ZS -	Government expenditure per secondary student as % of GDP per capita (%)
#
# SE.XPD.SECO.ZS - Expenditure on secondary as % of government expenditure on education (%)
#
# SE.XPD.TERT.PC.ZS - same tertiary
#
# SE.XPD.TERT.ZS
#
# SE.XPD.TOTL.GB.ZS - Expenditure on education as % of total government expenditure (%)
#
#
#
# ## lifestyle n stuff
#
# SP.POP.TOTL - Population, total
#
# IT.NET.USER.P2 - Internet users (per 100 people)
#
# per_allsp.cov_pop_tot - Coverage (%) -All Social Protection and Labor
#
# SG.VAW.REAS.ZS - Women who believe a husband is justified in beating his wife (any of five reasons) (%)
#
# SI.POV.2DAY - Poverty headcount ratio at dollar3.10 a day (2011 PPP) (% of population)
#
# SI.DST.10TH.10 - Income share held by highest 10%
#
# SI.SPR.PCAP.ZG -Annualized average growth rate in per capita real survey mean consumption or income, total population (%)
#
# SP.ADO.TFRT - Adolescent fertility rate (births per 1,000 women ages 15-19)
#
# SP.MTR.1519.ZS - Teenage mothers (% of women ages 15-19 who have had children or are currently pregnant)
#
# SP.DYN.CONU.ZS - Contraceptive prevalence (% of women ages 15-49)
#
# VC.IHR.PSRC.P5 - Intentional homicides (per 100,000 people)
